# %%
import pandas as pd
import missingno as msno

# %%
dados = pd.read_csv('agroclimatology.csv')

# %%
dados.head(3)
# Out:
#        data  codigo_ibge  latitude  longitude  T2M_RANGE     TS  T2MDEW  \
# 0  20030101      4100103  -23.3049   -50.3133      12.71  26.83   21.08
# 1  20030102      4100103  -23.3049   -50.3133       8.32  25.83   22.34
# 2  20030103      4100103  -23.3049   -50.3133       6.22  23.68   21.30
#
#    T2MWET  T2M_MAX  T2M_MIN  ...  GWETROOT  GWETPROF  ALLSKY_SFC_SW_DWN  \
# 0   23.77    33.15    20.43  ...      0.64      0.68              23.50
# 1   24.15    29.98    21.65  ...      0.65      0.68              18.79
# 2   22.49    27.04    20.82  ...      0.66      0.68              15.68
#
#    CLRSKY_SFC_SW_DWN  TOA_SW_DWN  ALLSKY_SFC_PAR_TOT  CLRSKY_SFC_PAR_TOT  \
# 0              30.53       42.75              129.63              165.10
# 1              29.75       42.74              104.59              160.21
# 2              29.39       42.72               88.91              157.65
#
#    ALLSKY_SFC_UVA  ALLSKY_SFC_UVB  ALLSKY_SFC_UV_INDEX
# ...

# %%
dados.describe() # lembrar de fazer rename nos labels
# Out:
#                data   codigo_ibge      latitude     longitude     T2M_RANGE  \
# count  2.294675e+06  2.294675e+06  2.294675e+06  2.294675e+06  2.294675e+06
# mean   2.011567e+07  4.114382e+06 -2.441340e+01 -5.199356e+01  1.118412e+01
# std    5.188631e+04  8.298590e+03  1.049249e+00  1.306068e+00  3.458950e+00
# min    2.003010e+07  4.100103e+06 -2.648390e+01 -5.458270e+01  1.080000e+00
# 25%    2.007070e+07  4.107256e+06 -2.539020e+01 -5.305350e+01  8.680000e+00
# 50%    2.012010e+07  4.114203e+06 -2.426820e+01 -5.205030e+01  1.114000e+01
# 75%    2.016070e+07  4.121604e+06 -2.348430e+01 -5.097540e+01  1.364000e+01
# max    2.020123e+07  4.128708e+06 -2.255230e+01 -4.906240e+01  2.401000e+01
#
#                  TS        T2MDEW        T2MWET       T2M_MAX       T2M_MIN  \
# count  2.294675e+06  2.294675e+06  2.294675e+06  2.294675e+06  2.294675e+06
# mean   2.148887e+01  1.636258e+01  1.885635e+01  2.741268e+01  1.622858e+01
# ...

# %%
dados_nulos = print(dados.isnull().sum())
# Out:
# data                   0
# codigo_ibge            0
# latitude               0
# longitude              0
# T2M_RANGE              0
# TS                     0
# T2MDEW                 0
# T2MWET                 0
# T2M_MAX                0
# T2M_MIN                0
# T2M                    0
# QV2M                   0
# RH2M                   0
# PRECTOTCORR            0
# PS                     0
# WS2M                   0
# WS2M_MAX               0
# WS2M_MIN               0
# WS2M_RANGE             0
# WS10M                  0
# WS10M_MAX              0
# WS10M_MIN              0
# WS10M_RANGE            0
# WS50M                  0
# WS50M_MAX              0
# WS50M_MIN              0
# WS50M_RANGE            0
# GWETTOP                0
# GWETROOT               0
# GWETPROF               0
# ALLSKY_SFC_SW_DWN      0
# CLRSKY_SFC_SW_DWN      0
# TOA_SW_DWN             0
# ALLSKY_SFC_PAR_TOT     0
# CLRSKY_SFC_PAR_TOT     0
# ALLSKY_SFC_UVA         0
# ALLSKY_SFC_UVB         0
# ...

# %%
msno.matrix(dados,figsize=(10,8)) # nulos plot
# Out:
# <AxesSubplot: >

# %%
dados_plot = dados.loc[:, ['T2M_RANGE', 'QV2M']] # variáveis explicativas

# %%
dados_plot.head()
# Out:
#    T2M_RANGE   QV2M
# 0      12.71  16.72
# 1       8.32  18.13
# 2       6.22  16.91
# 3       5.24  17.15
# 4       8.83  17.27

# %%
pip install ydata-profiling
# Out:
# ...
#
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ydata_profiling import ProfileReport # resumo dados

# %%
site_01 = ProfileReport(dados_plot) # plotagem dados correlações

# %%
site_01
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-01-13 14:34:31.435877&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ## Dataprep

# %%
def metadados(dataframe):
    """
    Gera um dataframe contendo metadados das colunas do dataframe fornecido.

    :param dataframe: DataFrame para o qual os metadados serão gerados.
    :return: DataFrame contendo metadados.
    """

    # Coleta de metadados básicos
    metadata = pd.DataFrame({
        'nome_variavel': dataframe.columns,
        'tipo': dataframe.dtypes,
        'qt_nulos': dataframe.isnull().sum(),
        'percent_nulos': round((dataframe.isnull().sum() / len(dataframe))* 100,2),
        'cardinalidade': dataframe.nunique(),
    })
    metadata=metadata.sort_values(by='percent_nulos',ascending=False)
    metadata = metadata.reset_index(drop=True)

    return metadata

# %%
metadata_df = metadados(dados_plot)
metadata_df.head(100)
# Out:
#   nome_variavel     tipo  qt_nulos  percent_nulos  cardinalidade
# 0     T2M_RANGE  float64         0            0.0           2068
# 1          QV2M  float64         0            0.0            303

# %%
#normalizando 
from sklearn.preprocessing import MinMaxScaler

# Instanciando o scaler
scaler = MinMaxScaler()

# Selecionando colunas numéricas
numeric_cols = dados_plot.select_dtypes(include=['float64', 'int64','int32']).columns

# Aplicando a normalização
dados_plot[numeric_cols] = scaler.fit_transform(dados_plot[numeric_cols])
dados_plot.shape
# Out:
# (2294675, 2)

# %%
dados_model = dados_plot #falta fazer merge via produtividade

# %%
dados_model.to_csv('variáveis_explicativas_agro.csv')
